# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/adars/Desktop/Practice_Python_Data/SFSalaries.csv")
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_11084\359288529.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/adars/Desktop/Practice_Python_Data/SFSalaries.csv")

# %%
#display top 10 rows
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
#display last 10 rows
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
#Find the shape of the dataset

df.shape
# Out:
# (148654, 13)

# %%
#datatypes of each column and memory requirements
# Bonus print the number of rows
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
print("the number of rows is",df.shape[0])
# Out:
# the number of rows is 148654

# %%
#memory requirements

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
#check null values

df.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#columns BasePay, Benefits,Notes, Status have null values

# %%
#Drop the ID, Notes, Agency and Status columns

df = df.drop(["Id","Notes","Agency","Status"],axis = 1)

# %%
df.shape
# Out:
# (148654, 9)

# %%
#Get Overall Statistics about the Dataframe
df.describe()
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# 50%     71426.610000      92404.090000    2013.000000
# 75%    105839.135000     132876.450000    2014.000000
# max    567595.430000     567595.430000    2014.000000

# %%
# Which 5 employee names show up most often

df["EmployeeName"].value_counts()
# Out:
# EmployeeName
# Kevin Lee                   13
# Richard Lee                 11
# Steven Lee                  11
# William Wong                11
# Stanley Lee                  9
#                             ..
# Jeffrey Skover               1
# Ken Dever                    1
# Kevin Whitfield              1
# Granville McCollough III     1
# Joe Lopez                    1
# Name: count, Length: 110811, dtype: int64

# %%
df["JobTitle"].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
len(df["JobTitle"].unique().sum())
# Out:
# 51389

# %%
# Total number of job titles containing the term "Captain"
len(df[df["JobTitle"].str.contains("CAPTAIN")])
# Out:
# 141

# %%
#But that's case sensitive, to account for upper and lowercase
len(df[df["JobTitle"].str.contains("CAPTAIN", case=False)])
# Out:
# 552

# %%
# Display all the employee names from the fire department
df[df["JobTitle"].str.contains("fire", case=False)]["EmployeeName"]
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %%
# 12 Find min, max, and average base pay

df["BasePay"].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 # 12 Find min, max, and average base pay
# ----> 3 df["BasePay"].min()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11669, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, numeric_only, **kwargs)
#   11650 @doc(
#   11651     _num_doc,
#   11652     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11667     **kwargs,
#   11668 ):
# > 11669     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11169, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11162 def min(
#   11163     self,
#   11164     axis: Axis | None = 0,
#    (...)
#   11167     **kwargs,
#   11168 ):
# > 11169     return self._stat_function(
#   11170         "min",
# ...

# %%
import numpy as np

df['BasePay']= df['BasePay'].replace("Not Provided",np.nan)
df['BasePay'].astype(float).describe()

# %%
# Replace the not provided in EmployeeNames column with NaN

df["EmployeeName"].replace("Not provided",np.nan)

# %%
# Drop any row that has more than 5 missing values
# No rows, because dropped employee null values earlier
df[df.isnull().sum(axis=1)==5]

# %%
#What job does Albert Pardini work?

df[df["EmployeeName"] == "Albert Pardini"]["JobTitle"]
# Out:
# 36519    Captain 3
# Name: JobTitle, dtype: object

# %%
#How much does Albert Pardini make including benefits?
df[df["EmployeeName"] == "Albert Pardini"]["TotalPayBenefits"]
# Out:
# 36519    253995.29
# Name: TotalPayBenefits, dtype: float64

# %%
df[df["EmployeeName"] == "Albert Pardini"]["TotalPay"]
# Out:
# 36519    207669.08
# Name: TotalPay, dtype: float64

# %%
#show the name of the person who has the highest base pay

df[df["BasePay"].astype(float).max() == df["BasePay"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 3
#       1 #show the name of the person who has the highest base pay
# ----> 3 df[df["BasePay"].astype(float).max() == df["BasePay"]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# find average basepay of employee with job title "Accountant"

df.columns

df.groupby("JobTitle").mean(['BasePay'])
# Out:
#                                                     TotalPay  \
# JobTitle
# ACCOUNT CLERK                                   44035.664337
# ACCOUNTANT                                      47429.268000
# ACCOUNTANT INTERN                               29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000
# ACUPUNCTURIST                                   67594.400000
# ...                                                      ...
# X-RAY LABORATORY AIDE                           52705.880385
# X-Ray Laboratory Aide                           50823.942700
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  53632.870000
# Youth Comm Advisor                              41414.307500
# ZOO CURATOR                                     66686.560000
#
#                                                 TotalPayBenefits     Year
# JobTitle
# ACCOUNT CLERK                                       44035.664337  2011.00
# ...
